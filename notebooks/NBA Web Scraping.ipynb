# %% [markdown]
# # DSCI 511: Data Aquistion and Preprocessing
#
# ## NBA API Final Project
#
# ### Members:
# * Dara Kasrovi
# * Ao Wang

# %% [markdown]
# ## Import Libraries

# %%
# !pip install pandas
# !pip install selenium
# !pip install webdriver-manager

# %%
import re
import json
import os
from concurrent import futures
from typing import List, Dict, Any

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

# %% [markdown]
# ## Get NBA Teams
#
# After running the function, the output should look like this:
#
# |   | Division | Team               |    Team ID |
# |--:|---------:|-------------------:|-----------:|
# | 0 | Atlantic |     Boston Celtics | 1610612738 |
# | 1 | Atlantic |      Brooklyn Nets | 1610612751 |
# | 2 | Atlantic |    New York Knicks | 1610612752 |
# | 3 | Atlantic | Philadelphia 76ers | 1610612755 |
# | 4 | Atlantic |    Toronto Raptors | 1610612761 |

# %%
def get_nba_teams() -> pd.DataFrame:
    """The function goes to the NBA team stats page and scrapes all the team data,
    including division, team, and team ID
    
    Returns:
        pd.DataFrame: the NBA teams
    """
    url = "https://www.nba.com/stats/teams"
    response = requests.get(url)
    
    # Check that the response was successful, i.e.  200 - good, 401, 404, etc - bad
    if not response.ok:
        print("Something went wrong in getting team listings")
        return pd.DataFrame()
    
    # Use bs4 and regex to get the table of teams
    soup = BeautifulSoup(response.content, "html.parser")
    regex = re.compile("^StatsTeamsList_divContent")
    table = soup.find("div", {"class": regex})
    
    # Atlantic, Central, Southeast, etc are basketball divisions
    chart = list(table.children)
    output = []
    
    # Get the division, team, and team id in the HTML
    for html in chart:
        division = html.find("h2").text
        teams = html.find_all("a")
        for team in teams:
            href = team["href"].replace("/stats/team/", "")
            team_name = team.text
            output.append([division, team_name, href])
    return pd.DataFrame(output, columns=["Division", "Team", "Team ID"])

# %%
teams = get_nba_teams()
teams
# Out:
#      Division                    Team     Team ID
# 0    Atlantic          Boston Celtics  1610612738
# 1    Atlantic           Brooklyn Nets  1610612751
# 2    Atlantic         New York Knicks  1610612752
# 3    Atlantic      Philadelphia 76ers  1610612755
# 4    Atlantic         Toronto Raptors  1610612761
# 5     Central           Chicago Bulls  1610612741
# 6     Central     Cleveland Cavaliers  1610612739
# 7     Central         Detroit Pistons  1610612765
# 8     Central          Indiana Pacers  1610612754
# 9     Central         Milwaukee Bucks  1610612749
# 10  Southeast           Atlanta Hawks  1610612737
# 11  Southeast       Charlotte Hornets  1610612766
# 12  Southeast              Miami Heat  1610612748
# 13  Southeast           Orlando Magic  1610612753
# 14  Southeast      Washington Wizards  1610612764
# 15  Northwest          Denver Nuggets  1610612743
# 16  Northwest  Minnesota Timberwolves  1610612750
# 17  Northwest   Oklahoma City Thunder  1610612760
# 18  Northwest  Portland Trail Blazers  1610612757
# 19  Northwest               Utah Jazz  1610612762
# 20    Pacific   Golden State Warriors  1610612744
# 21    Pacific             LA Clippers  1610612746
# 22    Pacific      Los Angeles Lakers  1610612747
# 23    Pacific            Phoenix Suns  1610612756
# 24    Pacific        Sacramento Kings  1610612758
# 25  Southwest        Dallas Mavericks  1610612742
# 26  Southwest         Houston Rockets  1610612745
# 27  Southwest       Memphis Grizzlies  1610612763
# 28  Southwest    New Orleans Pelicans  1610612740
# 29  Southwest       San Antonio Spurs  1610612759

# %% [markdown]
# ## Save NBA Teams to Directory

# %%
# if not os.path.isdir("data"):
#     os.makedirs("data")
# teams.to_csv(os.path.join("data", "teams.csv"))

# %% [markdown]
# ## Get Team Roster

# %%
def create_team_query(team_id: int, season: str = "2022-23") -> str:
    """Create URL for team roster
    
    Args:
        team_id (int): the NBA team ID, i.e. 1610612755
        season (str): the year of the roster, i.e. 2022-23
    
    Returns:
        str: the URL for team roster
    """
    return f"https://www.nba.com/stats/team/{team_id}?Season={season}"

# %%
def get_team_roster(team_id: int, season: str = "2022-23") -> pd.DataFrame:
    """Gets the NBA team roster
    
    Args:
        team_id (int): the NBA team ID, i.e. 1610612755
        season (str): the year of the roster, i.e. 2022-23
    
    Returns:
        pd.DataFrame: the NBA team roster
    """
    print(team_id)
    url = create_team_query(team_id=team_id, season=season)
    response = requests.get(url)
    i = 0
    
    # There are times where requests return a 502 - bad gateway,
    # so just in case, make multiple requests
    while not response.ok:
        print(f"There was an issue getting team id={team_id}!!")
        print(f"Reattempting! Iteration {i + 1}")
        i += 1
        response = requests.get(url)
    
    # Find roster information
    soup = BeautifulSoup(response.content, "html.parser")
    output = json.loads(soup.find("script", {"id": "__NEXT_DATA__"}).text)
    return pd.DataFrame(output["props"]["pageProps"]["team"]["roster"])

# %%
philly_team = get_team_roster(team_id=1610612755)
philly_team
# Out:
# 1610612755
#         TeamID SEASON LeagueID              PLAYER    NICKNAME  \
# 0   1610612755   2022       00        Tyrese Maxey      Tyrese
# 1   1610612755   2022       00        James Harden       James
# 2   1610612755   2022       00    Montrezl Harrell    Montrezl
# 3   1610612755   2022       00   De'Anthony Melton  De'Anthony
# 4   1610612755   2022       00      Jaden Springer       Jaden
# 5   1610612755   2022       00       Tobias Harris      Tobias
# 6   1610612755   2022       00         P.J. Tucker        P.J.
# 7   1610612755   2022       00        Shake Milton       Shake
# 8   1610612755   2022       00       Georges Niang     Georges
# 9   1610612755   2022       00         Joel Embiid        Joel
# 10  1610612755   2022       00    Matisse Thybulle     Matisse
# 11  1610612755   2022       00    Danuel House Jr.      Danuel
# 12  1610612755   2022       00      Furkan Korkmaz      Furkan
# 13  1610612755   2022       00  Michael Foster Jr.     Michael
# 14  1610612755   2022       00           Paul Reed        Paul
# 15  1610612755   2022       00   Julian Champagnie      Julian
#
#           PLAYER_SLUG NUM POSITION HEIGHT WEIGHT    BIRTH_DATE  AGE EXP  \
# 0        tyrese-maxey   0        G    6-2    200  NOV 04, 2000   22   2
# 1        james-harden   1        G    6-5    220  AUG 26, 1989   33  13
# 2    montrezl-harrell   5      F-C    6-7    240  JAN 26, 1994   28   7
# 3    deanthony-melton   8        G    6-2    200  MAY 28, 1998   24   4
# 4      jaden-springer  11        G    6-4    202  SEP 25, 2002   20   1
# 5       tobias-harris  12        F    6-7    226  JUL 15, 1992   30  11
# 6           pj-tucker  17        F    6-5    245  MAY 05, 1985   37  11
# 7        shake-milton  18      G-F    6-5    205  SEP 26, 1996   26   4
# 8       georges-niang  20        F    6-7    230  JUN 17, 1993   29   6
# 9         joel-embiid  21      C-F    7-0    280  MAR 16, 1994   28   6
# 10   matisse-thybulle  22      G-F    6-5    201  MAR 04, 1997   25   3
# 11    danuel-house-jr  25      F-G    6-6    220  JUN 07, 1993   29   6
# 12     furkan-korkmaz  30      G-F    6-7    202  JUL 24, 1997   25   5
# 13  michael-foster-jr  35        F    6-8    250  JAN 16, 2003   19   R
# 14          paul-reed  44        F    6-9    210  JUN 14, 1999   23   2
# 15  julian-champagnie  55        F    6-7    217  JUN 29, 2001   21   R
#
#                  SCHOOL  PLAYER_ID                              HOW_ACQUIRED
# 0              Kentucky    1630178                    #21 Pick in 2020 Draft
# 1         Arizona State     201935               Traded from BKN on 02/10/22
# 2            Louisville    1626149                        Signed on 09/13/22
# 3   Southern California    1629001               Traded from MEM on 06/24/22
# 4             Tennessee    1630531                    #28 Pick in 2021 Draft
# 5             Tennessee     202699               Traded from LAC on 02/06/19
# 6                 Texas     200782                        Signed on 07/06/22
# 7    Southern Methodist    1629003  Draft Rights Traded from DAL on 06/22/18
# 8            Iowa State    1627777                        Signed on 08/06/21
# 9                Kansas     203954                     #3 Pick in 2014 Draft
# 10           Washington    1629680  Draft Rights Traded from BOS on 06/21/19
# 11            Texas A&M    1627863                        Signed on 07/06/22
# 12         Anadolu Efes    1627788                    #26 Pick in 2016 Draft
# 13  NBA G League Ignite    1630701                        Signed on 07/10/22
# 14               DePaul    1630194                    #58 Pick in 2020 Draft
# 15           St. John's    1630577                        Signed on 07/02/22

# %% [markdown]
# ## Get all Players in NBA

# %%
def get_all_players(team_ids: List[int]) -> pd.DataFrame:
    """Get team rosters from all teams in NBA
    
    Args: 
        team_ids (List[int]): list of team IDs
    
    Returns:
        pd.DataFrame: all the NBA players
    """
    
    # Used threads to speed up queries
    with futures.ThreadPoolExecutor() as executor:
        player_list = list(executor.map(get_team_roster, team_ids))
    return pd.concat(player_list).reset_index(drop=True)

# %%
players = get_all_players(team_ids=teams["Team ID"].to_list())
players
# Out:
# 1610612738
# 1610612751
# 1610612752
# 1610612755
# 1610612761
# 1610612741
# 1610612739
# 1610612765
# 1610612754
# 1610612749
# 1610612737
# 1610612766
# 1610612748
# 1610612753
# 1610612764
# 1610612743
# 1610612750
# 1610612760
# 1610612757
# 1610612762
# 1610612744
# 1610612746
# 1610612747
# 1610612756
# 1610612758
# 1610612742
# 1610612745
# 1610612763
# 1610612740
# 1610612759
#          TeamID SEASON LeagueID            PLAYER NICKNAME       PLAYER_SLUG  \
# 0    1610612738   2022       00      Jayson Tatum   Jayson      jayson-tatum
# 1    1610612738   2022       00       Noah Vonleh     Noah       noah-vonleh
# 2    1610612738   2022       00      Jaylen Brown   Jaylen      jaylen-brown
# 3    1610612738   2022       00  Danilo Gallinari   Danilo  danilo-gallinari
# 4    1610612738   2022       00     Derrick White  Derrick     derrick-white
# ..          ...    ...      ...               ...      ...               ...
# 496  1610612759   2022       00  Keita Bates-Diop    Keita  keita-bates-diop
# 497  1610612759   2022       00         Tre Jones      Tre         tre-jones
# 498  1610612759   2022       00    Romeo Langford    Romeo    romeo-langford
# 499  1610612759   2022       00      Gorgui Dieng   Gorgui      gorgui-dieng
# 500  1610612759   2022       00       Jordan Hall   Jordan       jordan-hall
#
#     NUM POSITION HEIGHT WEIGHT    BIRTH_DATE  AGE EXP             SCHOOL  \
# 0     0      F-G    6-8    210  MAR 03, 1998   24   5               Duke
# 1     4        F   6-10    257  AUG 24, 1995   27   7            Indiana
# 2     7      G-F    6-6    223  OCT 24, 1996   26   6         California
# 3     8        F   6-10    236  AUG 08, 1988   34  13     Olimpia Milano
# 4     9        G    6-4    190  JUL 02, 1994   28   5           Colorado
# ..   ..      ...    ...    ...           ...  ...  ..                ...
# 496  31        F    6-8    229  JAN 23, 1996   26   4         Ohio State
# 497  33        G    6-1    185  JAN 08, 2000   22   2               Duke
# 498  35      G-F    6-5    216  OCT 25, 1999   23   3            Indiana
# 499  41        C   6-10    248  JAN 18, 1990   32   9         Louisville
# 500  55        G    6-7    215  JAN 14, 2002   20   R  St. Joseph's (PA)
#
#      PLAYER_ID                 HOW_ACQUIRED
# 0      1628369        #3 Pick in 2017 Draft
# 1       203943           Signed on 09/07/22
# 2      1627759        #3 Pick in 2016 Draft
# 3       201568           Signed on 07/12/22
# 4      1628401  Traded from SAS on 02/10/22
# ..         ...                          ...
# 496    1628966           Signed on 11/29/20
# 497    1630200       #41 Pick in 2020 Draft
# 498    1629641  Traded from BOS on 02/10/22
# 499     203476           Signed on 08/09/22
# 500    1631160           Signed on 08/11/22
#
# [501 rows x 16 columns]

# %% [markdown]
# ## Preprocess Team Roster

# %%
def feet_to_meter(height: str) -> float:
    """Converts feet'inches to meters"""
    feet, inches = list(map(int, height.split("-")))
    foot_to_inch_conversion = 12
    inch_to_meter = 2.54
    return (feet * foot_to_inch_conversion + inches) * inch_to_meter

def process_team_roster(df: pd.DataFrame) -> pd.DataFrame:
    """Cleans the team roster data"""
    pounds_to_kilograms = 0.45359237
    output = df.copy(deep=True)
    
    # Drop columns we don't need
    output.drop(columns=["LeagueID", "NICKNAME", "PLAYER_SLUG", "HOW_ACQUIRED"], inplace=True)
    
    # Format columns to have title case and reformat columns with ID
    output.columns = output.columns.str.title()
    output.rename(columns={
        "Teamid": "Team ID",
        "Player_Id": "Player ID",
        "Birth_Date": "Birth Date"
    }, inplace=True)
    
    # Convert feet and inches to meter
    output["Height"] = output["Height"].map(feet_to_meter)
    output["Age"] = output["Age"].astype(int)
    
    # Convert pounds to kilograms
    output["Weight"] = output["Weight"].astype(int)
    output["Weight"] = output["Weight"].map(lambda weight: weight * pounds_to_kilograms)
    
    # Convert to DateTime
    output["Birth Date"] = pd.to_datetime(output["Birth Date"])
    return output

# %%
processed_team_roster = process_team_roster(df=players)
processed_team_roster
# Out:
#         Team ID Season            Player Num Position  Height      Weight  \
# 0    1610612738   2022      Jayson Tatum   0      F-G  203.20   95.254398
# 1    1610612738   2022       Noah Vonleh   4        F  208.28  116.573239
# 2    1610612738   2022      Jaylen Brown   7      G-F  198.12  101.151099
# 3    1610612738   2022  Danilo Gallinari   8        F  208.28  107.047799
# 4    1610612738   2022     Derrick White   9        G  193.04   86.182550
# ..          ...    ...               ...  ..      ...     ...         ...
# 496  1610612759   2022  Keita Bates-Diop  31        F  203.20  103.872653
# 497  1610612759   2022         Tre Jones  33        G  185.42   83.914588
# 498  1610612759   2022    Romeo Langford  35      G-F  195.58   97.975952
# 499  1610612759   2022      Gorgui Dieng  41        C  208.28  112.490908
# 500  1610612759   2022       Jordan Hall  55        G  200.66   97.522360
#
#     Birth Date  Age Exp             School  Player ID
# 0   1998-03-03   24   5               Duke    1628369
# 1   1995-08-24   27   7            Indiana     203943
# 2   1996-10-24   26   6         California    1627759
# 3   1988-08-08   34  13     Olimpia Milano     201568
# 4   1994-07-02   28   5           Colorado    1628401
# ..         ...  ...  ..                ...        ...
# 496 1996-01-23   26   4         Ohio State    1628966
# 497 2000-01-08   22   2               Duke    1630200
# 498 1999-10-25   23   3            Indiana    1629641
# 499 1990-01-18   32   9         Louisville     203476
# 500 2002-01-14   20   R  St. Joseph's (PA)    1631160
#
# [501 rows x 12 columns]

# %%
# processed_team_roster.to_csv(os.path.join("nba", "players.csv"))

# %% [markdown]
# ## Get Player Dashboard Stats

# %%
def create_player_query(player_id: int) -> str:
    """Creates URL for player career regular season stats
    
    Args:
        player_id (int): the player's ID
    
    Returns:
        str: the URL for player stats
    """
    return f"https://www.nba.com/stats/player/{player_id}/career?PerMode=Totals"

# %%
def get_quick_stats(player_id: int) -> Dict[str, Any]:
    """The function gets a player's quick stats that show up on the dashboard, such as the
    PPG, RPG, APG, and PIE

    Args:
        player_id (int): the player's ID
    
    Returns:
        Dict[str, Any]: the player's quick stats
    """
    url = create_player_query(player_id=player_id)
    print(url)
    
    player_response = requests.get(url)
    player_soup = BeautifulSoup(player_response.content, "html.parser")
    regex = re.compile("PlayerSummary_playerStat*")
    player_stats = player_soup.find_all("div", class_=regex)
    
    stats = {"Player ID": player_id}
    for i in player_stats:
        stat_tags = list(i.children)
        label, value = stat_tags
        stats[label.text] = float(value.text) if value.text != "--" else np.nan
    return stats

# %%
def get_all_player_quick_stats(player_ids: List[int]) -> pd.DataFrame:
    """Get all the NBA player's quick stats from the dashboard
    
    Args:
        player_ids (List[int]): all the player's IDs
    
    Returns:
        pd.DataFrame: all the player's quick stats
    """
    # Used threads to speed up queries
    with futures.ThreadPoolExecutor() as executor:
        player_list = list(executor.map(get_quick_stats, player_ids))
    return pd.DataFrame(player_list)

# %%
player_ids = players["PLAYER_ID"].to_list()
quick_stats = get_all_player_quick_stats(player_ids=player_ids)
quick_stats
# Out:
# https://www.nba.com/stats/player/1628369/career?PerMode=Totalshttps://www.nba.com/stats/player/203943/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1627759/career?PerMode=Totals
# https://www.nba.com/stats/player/201568/career?PerMode=Totals
# https://www.nba.com/stats/player/1628401/career?PerMode=Totals
# https://www.nba.com/stats/player/1630202/career?PerMode=Totals
# https://www.nba.com/stats/player/1629684/career?PerMode=Totals
# https://www.nba.com/stats/player/1627763/career?PerMode=Totals
# https://www.nba.com/stats/player/1631120/career?PerMode=Totals
# https://www.nba.com/stats/player/1629662/career?PerMode=Totals
# https://www.nba.com/stats/player/1630573/career?PerMode=Totals
# https://www.nba.com/stats/player/203935/career?PerMode=Totals
# https://www.nba.com/stats/player/1628436/career?PerMode=Totals
# https://www.nba.com/stats/player/201143/career?PerMode=Totals
# https://www.nba.com/stats/player/1629057/career?PerMode=Totals
# https://www.nba.com/stats/player/1628382/career?PerMode=Totals
# https://www.nba.com/stats/player/201933/career?PerMode=Totals
# https://www.nba.com/stats/player/1626220/career?PerMode=Totals
# https://www.nba.com/stats/player/203933/career?PerMode=Totals
# https://www.nba.com/stats/player/1628410/career?PerMode=Totals
# https://www.nba.com/stats/player/1630561/career?PerMode=Totals
# https://www.nba.com/stats/player/201142/career?PerMode=Totals
# https://www.nba.com/stats/player/201988/career?PerMode=Totals
# https://www.nba.com/stats/player/1627732/career?PerMode=Totals
# https://www.nba.com/stats/player/202681/career?PerMode=Totals
# https://www.nba.com/stats/player/203925/career?PerMode=Totals
# https://www.nba.com/stats/player/202693/career?PerMode=Totals
# https://www.nba.com/stats/player/1630556/career?PerMode=Totals
# https://www.nba.com/stats/player/1629139/career?PerMode=Totals
# https://www.nba.com/stats/player/1630549/career?PerMode=Totals
# https://www.nba.com/stats/player/1630560/career?PerMode=Totals
# https://www.nba.com/stats/player/203552/career?PerMode=Totals
# https://www.nba.com/stats/player/1631214/career?PerMode=Totals
# https://www.nba.com/stats/player/1629651/career?PerMode=Totals
# https://www.nba.com/stats/player/1629629/career?PerMode=Totals
# https://www.nba.com/stats/player/1630167/career?PerMode=Totals
# https://www.nba.com/stats/player/1630540/career?PerMode=Totals
# https://www.nba.com/stats/player/1631211/career?PerMode=Totals
# https://www.nba.com/stats/player/201565/career?PerMode=Totals
# https://www.nba.com/stats/player/1630193/career?PerMode=Totals
# https://www.nba.com/stats/player/1629656/career?PerMode=Totals
# https://www.nba.com/stats/player/1629628/career?PerMode=Totals
# https://www.nba.com/stats/player/1628973/career?PerMode=Totals
# https://www.nba.com/stats/player/203095/career?PerMode=Totals
# https://www.nba.com/stats/player/1629004/career?PerMode=Totals
# https://www.nba.com/stats/player/1629011/career?PerMode=Totals
# https://www.nba.com/stats/player/203944/career?PerMode=Totals
# https://www.nba.com/stats/player/1630624/career?PerMode=Totals
# https://www.nba.com/stats/player/1630579/career?PerMode=Totals
# https://www.nba.com/stats/player/1627853/career?PerMode=Totals
# https://www.nba.com/stats/player/1628392/career?PerMode=Totals
# https://www.nba.com/stats/player/1630178/career?PerMode=Totals
# https://www.nba.com/stats/player/201935/career?PerMode=Totals
# https://www.nba.com/stats/player/1626149/career?PerMode=Totals
# https://www.nba.com/stats/player/1629001/career?PerMode=Totals
# https://www.nba.com/stats/player/1630531/career?PerMode=Totals
# https://www.nba.com/stats/player/202699/career?PerMode=Totals
# https://www.nba.com/stats/player/200782/career?PerMode=Totals
# https://www.nba.com/stats/player/1629003/career?PerMode=Totals
# https://www.nba.com/stats/player/1627777/career?PerMode=Totals
# https://www.nba.com/stats/player/203954/career?PerMode=Totals
# https://www.nba.com/stats/player/1629680/career?PerMode=Totals
# https://www.nba.com/stats/player/1627863/career?PerMode=Totals
# https://www.nba.com/stats/player/1627788/career?PerMode=Totals
# https://www.nba.com/stats/player/1630701/career?PerMode=Totals
# https://www.nba.com/stats/player/1630194/career?PerMode=Totals
# https://www.nba.com/stats/player/1630577/career?PerMode=Totals
# https://www.nba.com/stats/player/1628384/career?PerMode=Totals
# https://www.nba.com/stats/player/1630567/career?PerMode=Totals
# https://www.nba.com/stats/player/1630173/career?PerMode=Totals
# https://www.nba.com/stats/player/1631199/career?PerMode=Totals
# https://www.nba.com/stats/player/1630551/career?PerMode=Totals
# https://www.nba.com/stats/player/1630288/career?PerMode=Totals
# https://www.nba.com/stats/player/201152/career?PerMode=Totals
# https://www.nba.com/stats/player/1630201/career?PerMode=Totalshttps://www.nba.com/stats/player/1627832/career?PerMode=Totals
# https://www.nba.com/stats/player/203920/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1628449/career?PerMode=Totals
# https://www.nba.com/stats/player/203490/career?PerMode=Totals
# https://www.nba.com/stats/player/1629018/career?PerMode=Totals
# https://www.nba.com/stats/player/1631132/career?PerMode=Totals
# https://www.nba.com/stats/player/1627823/career?PerMode=Totals
# https://www.nba.com/stats/player/1627783/career?PerMode=Totals
# https://www.nba.com/stats/player/1630625/career?PerMode=Totals
# https://www.nba.com/stats/player/1629632/career?PerMode=Totals
# https://www.nba.com/stats/player/1628366/career?PerMode=Totals
# https://www.nba.com/stats/player/203083/career?PerMode=Totals
# https://www.nba.com/stats/player/1627884/career?PerMode=Totals
# https://www.nba.com/stats/player/1627936/career?PerMode=Totals
# https://www.nba.com/stats/player/201609/career?PerMode=Totals
# https://www.nba.com/stats/player/203897/career?PerMode=Totals
# https://www.nba.com/stats/player/202696/career?PerMode=Totals
# https://www.nba.com/stats/player/201942/career?PerMode=Totals
# https://www.nba.com/stats/player/1630245/career?PerMode=Totals
# https://www.nba.com/stats/player/1628396/career?PerMode=Totals
# https://www.nba.com/stats/player/1630792/career?PerMode=Totals
# https://www.nba.com/stats/player/1630250/career?PerMode=Totals
# https://www.nba.com/stats/player/1629750/career?PerMode=Totals
# https://www.nba.com/stats/player/1631207/career?PerMode=Totals
# https://www.nba.com/stats/player/1628961/career?PerMode=Totals
# https://www.nba.com/stats/player/1630172/career?PerMode=Totals
# https://www.nba.com/stats/player/201567/career?PerMode=Totals
# https://www.nba.com/stats/player/1627747/career?PerMode=Totals
# https://www.nba.com/stats/player/1630596/career?PerMode=Totals
# https://www.nba.com/stats/player/1630205/career?PerMode=Totals
# https://www.nba.com/stats/player/1629685/career?PerMode=Totals
# https://www.nba.com/stats/player/1629636/career?PerMode=Totals
# https://www.nba.com/stats/player/201937/career?PerMode=Totals
# https://www.nba.com/stats/player/1630600/career?PerMode=Totals
# https://www.nba.com/stats/player/1626224/career?PerMode=Totals
# https://www.nba.com/stats/player/203526/career?PerMode=Totals
# https://www.nba.com/stats/player/1629603/career?PerMode=Totals
# https://www.nba.com/stats/player/1628386/career?PerMode=Totals
# https://www.nba.com/stats/player/1629731/career?PerMode=Totals
# https://www.nba.com/stats/player/201577/career?PerMode=Totals
# https://www.nba.com/stats/player/1630171/career?PerMode=Totals
# https://www.nba.com/stats/player/1628378/career?PerMode=Totals
# https://www.nba.com/stats/player/1631105/career?PerMode=Totals
# https://www.nba.com/stats/player/1630595/career?PerMode=Totals
# https://www.nba.com/stats/player/203457/career?PerMode=Totals
# https://www.nba.com/stats/player/202692/career?PerMode=Totals
# https://www.nba.com/stats/player/1628977/career?PerMode=Totals
# https://www.nba.com/stats/player/1630165/career?PerMode=Totals
# https://www.nba.com/stats/player/1630296/career?PerMode=Totals
# https://www.nba.com/stats/player/1630587/career?PerMode=Totals
# https://www.nba.com/stats/player/203585/career?PerMode=Totals
# https://www.nba.com/stats/player/202709/career?PerMode=Totals
# https://www.nba.com/stats/player/1628995/career?PerMode=Totals
# https://www.nba.com/stats/player/1631205/career?PerMode=Totals
# https://www.nba.com/stats/player/1631093/career?PerMode=Totals
# https://www.nba.com/stats/player/1630191/career?PerMode=Totalshttps://www.nba.com/stats/player/1628963/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1630180/career?PerMode=Totals
# https://www.nba.com/stats/player/202711/career?PerMode=Totals
# https://www.nba.com/stats/player/1630169/career?PerMode=Totals
# https://www.nba.com/stats/player/1631097/career?PerMode=Totals
# https://www.nba.com/stats/player/1629614/career?PerMode=Totals
# https://www.nba.com/stats/player/1630537/career?PerMode=Totals
# https://www.nba.com/stats/player/1630243/career?PerMode=Totals
# https://www.nba.com/stats/player/204456/career?PerMode=Totals
# https://www.nba.com/stats/player/1631112/career?PerMode=Totals
# https://www.nba.com/stats/player/1629052/career?PerMode=Totals
# https://www.nba.com/stats/player/201949/career?PerMode=Totals
# https://www.nba.com/stats/player/1630678/career?PerMode=Totals
# https://www.nba.com/stats/player/1630543/career?PerMode=Totals
# https://www.nba.com/stats/player/1630174/career?PerMode=Totals
# https://www.nba.com/stats/player/1627741/career?PerMode=Totalshttps://www.nba.com/stats/player/1630188/career?PerMode=Totals
# https://www.nba.com/stats/player/1628464/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1626167/career?PerMode=Totals
# https://www.nba.com/stats/player/1629048/career?PerMode=Totals
# https://www.nba.com/stats/player/1630699/career?PerMode=Totals
# https://www.nba.com/stats/player/201588/career?PerMode=Totals
# https://www.nba.com/stats/player/1628975/career?PerMode=Totals
# https://www.nba.com/stats/player/204060/career?PerMode=Totals
# https://www.nba.com/stats/player/1626171/career?PerMode=Totals
# https://www.nba.com/stats/player/201572/career?PerMode=Totals
# https://www.nba.com/stats/player/1628960/career?PerMode=Totals
# https://www.nba.com/stats/player/1629670/career?PerMode=Totals
# https://www.nba.com/stats/player/1631260/career?PerMode=Totals
# https://www.nba.com/stats/player/201950/career?PerMode=Totals
# https://www.nba.com/stats/player/203114/career?PerMode=Totals
# https://www.nba.com/stats/player/202083/career?PerMode=Totals
# https://www.nba.com/stats/player/1626192/career?PerMode=Totals
# https://www.nba.com/stats/player/201586/career?PerMode=Totals
# https://www.nba.com/stats/player/203507/career?PerMode=Totals
# https://www.nba.com/stats/player/203648/career?PerMode=Totals
# https://www.nba.com/stats/player/1630572/career?PerMode=Totals
# https://www.nba.com/stats/player/1626163/career?PerMode=Totals
# https://www.nba.com/stats/player/1630552/career?PerMode=Totals
# https://www.nba.com/stats/player/1630235/career?PerMode=Totals
# https://www.nba.com/stats/player/1628988/career?PerMode=Totals
# https://www.nba.com/stats/player/1627749/career?PerMode=Totals
# https://www.nba.com/stats/player/1629633/career?PerMode=Totals
# https://www.nba.com/stats/player/203200/career?PerMode=Totals
# https://www.nba.com/stats/player/1629027/career?PerMode=Totals
# https://www.nba.com/stats/player/1629631/career?PerMode=Totals
# https://www.nba.com/stats/player/203992/career?PerMode=Totals
# https://www.nba.com/stats/player/1631100/career?PerMode=Totals
# https://www.nba.com/stats/player/203991/career?PerMode=Totals
# https://www.nba.com/stats/player/1630168/career?PerMode=Totals
# https://www.nba.com/stats/player/1628381/career?PerMode=Totals
# https://www.nba.com/stats/player/1631213/career?PerMode=Totals
# https://www.nba.com/stats/player/1630249/career?PerMode=Totals
# https://www.nba.com/stats/player/1630163/career?PerMode=Totals
# https://www.nba.com/stats/player/1630547/career?PerMode=Totals
# https://www.nba.com/stats/player/1626179/career?PerMode=Totals
# https://www.nba.com/stats/player/1630208/career?PerMode=Totals
# https://www.nba.com/stats/player/1631109/career?PerMode=Totals
# https://www.nba.com/stats/player/1629667/career?PerMode=Totals
# https://www.nba.com/stats/player/1631121/career?PerMode=Totals
# https://www.nba.com/stats/player/1628372/career?PerMode=Totals
# https://www.nba.com/stats/player/1630177/career?PerMode=Totals
# https://www.nba.com/stats/player/1628998/career?PerMode=Totals
# https://www.nba.com/stats/player/1626162/career?PerMode=Totals
# https://www.nba.com/stats/player/202330/career?PerMode=Totals
# https://www.nba.com/stats/player/1630550/career?PerMode=Totals
# https://www.nba.com/stats/player/1630539/career?PerMode=Totals
# https://www.nba.com/stats/player/203486/career?PerMode=Totals
# https://www.nba.com/stats/player/1629023/career?PerMode=Totals
# https://www.nba.com/stats/player/1629216/career?PerMode=Totals
# https://www.nba.com/stats/player/203506/career?PerMode=Totals
# https://www.nba.com/stats/player/1631107/career?PerMode=Totals
# https://www.nba.com/stats/player/200768/career?PerMode=Totals
# https://www.nba.com/stats/player/1631288/career?PerMode=Totals
# https://www.nba.com/stats/player/1628389/career?PerMode=Totals
# https://www.nba.com/stats/player/1629639/career?PerMode=Totals
# https://www.nba.com/stats/player/1628997/career?PerMode=Totals
# https://www.nba.com/stats/player/203473/career?PerMode=Totals
# https://www.nba.com/stats/player/202710/career?PerMode=Totals
# https://www.nba.com/stats/player/1629312/career?PerMode=Totals
# https://www.nba.com/stats/player/1631115/career?PerMode=Totals
# https://www.nba.com/stats/player/1629622/career?PerMode=Totals
# https://www.nba.com/stats/player/2617/career?PerMode=Totals
# https://www.nba.com/stats/player/1629130/career?PerMode=Totals
# https://www.nba.com/stats/player/1630209/career?PerMode=Totals
# https://www.nba.com/stats/player/1628371/career?PerMode=Totals
# https://www.nba.com/stats/player/1631216/career?PerMode=Totals
# https://www.nba.com/stats/player/1629643/career?PerMode=Totals
# https://www.nba.com/stats/player/1630591/career?PerMode=Totals
# https://www.nba.com/stats/player/1631094/career?PerMode=Totals
# https://www.nba.com/stats/player/1630284/career?PerMode=Totals
# https://www.nba.com/stats/player/1629626/career?PerMode=Totals
# https://www.nba.com/stats/player/1628964/career?PerMode=Totals
# https://www.nba.com/stats/player/1630181/career?PerMode=Totals
# https://www.nba.com/stats/player/203914/career?PerMode=Totals
# https://www.nba.com/stats/player/1628365/career?PerMode=Totals
# https://www.nba.com/stats/player/1629021/career?PerMode=Totals
# https://www.nba.com/stats/player/1630532/career?PerMode=Totals
# https://www.nba.com/stats/player/1629678/career?PerMode=Totals
# https://www.nba.com/stats/player/203082/career?PerMode=Totals
# https://www.nba.com/stats/player/1628976/career?PerMode=Totals
# https://www.nba.com/stats/player/1630175/career?PerMode=Totals
# https://www.nba.com/stats/player/1631098/career?PerMode=Totals
# https://www.nba.com/stats/player/203078/career?PerMode=Totalshttps://www.nba.com/stats/player/203115/career?PerMode=Totals
#
# https://www.nba.com/stats/player/204001/career?PerMode=Totals
# https://www.nba.com/stats/player/1630692/career?PerMode=Totals
# https://www.nba.com/stats/player/1629060/career?PerMode=Totals
# https://www.nba.com/stats/player/1630166/career?PerMode=Totals
# https://www.nba.com/stats/player/1630176/career?PerMode=Totals
# https://www.nba.com/stats/player/1630225/career?PerMode=Totals
# https://www.nba.com/stats/player/1630264/career?PerMode=Totals
# https://www.nba.com/stats/player/1630648/career?PerMode=Totals
# https://www.nba.com/stats/player/1629655/career?PerMode=Totals
# https://www.nba.com/stats/player/1628420/career?PerMode=Totals
# https://www.nba.com/stats/player/1630557/career?PerMode=Totals
# https://www.nba.com/stats/player/1628398/career?PerMode=Totals
# https://www.nba.com/stats/player/1626153/career?PerMode=Totals
# https://www.nba.com/stats/player/201959/career?PerMode=Totals
# https://www.nba.com/stats/player/1631128/career?PerMode=Totals
# https://www.nba.com/stats/player/1629008/career?PerMode=Totals
# https://www.nba.com/stats/player/1630538/career?PerMode=Totals
# https://www.nba.com/stats/player/203484/career?PerMode=Totals
# https://www.nba.com/stats/player/201599/career?PerMode=Totals
# https://www.nba.com/stats/player/1631212/career?PerMode=Totals
# https://www.nba.com/stats/player/1628432/career?PerMode=Totals
# https://www.nba.com/stats/player/1631298/career?PerMode=Totals
# https://www.nba.com/stats/player/1628971/career?PerMode=Totals
# https://www.nba.com/stats/player/202397/career?PerMode=Totals
# https://www.nba.com/stats/player/203999/career?PerMode=Totals
# https://www.nba.com/stats/player/1631221/career?PerMode=Totals
# https://www.nba.com/stats/player/1630192/career?PerMode=Totals
# https://www.nba.com/stats/player/1627750/career?PerMode=Totals
# https://www.nba.com/stats/player/1628427/career?PerMode=Totals
# https://www.nba.com/stats/player/201145/career?PerMode=Totals
# https://www.nba.com/stats/player/203932/career?PerMode=Totals
# https://www.nba.com/stats/player/1626156/career?PerMode=Totals
# https://www.nba.com/stats/player/1630162/career?PerMode=Totals
# https://www.nba.com/stats/player/1630183/career?PerMode=Totals
# https://www.nba.com/stats/player/1629669/career?PerMode=Totals
# https://www.nba.com/stats/player/203937/career?PerMode=Totals
# https://www.nba.com/stats/player/1630639/career?PerMode=Totals
# https://www.nba.com/stats/player/1629162/career?PerMode=Totals
# https://www.nba.com/stats/player/1631111/career?PerMode=Totals
# https://www.nba.com/stats/player/1631169/career?PerMode=Totals
# https://www.nba.com/stats/player/1627854/career?PerMode=Totals
# https://www.nba.com/stats/player/1629675/career?PerMode=Totals
# https://www.nba.com/stats/player/1627752/career?PerMode=Totals
# https://www.nba.com/stats/player/1630233/career?PerMode=Totals
# https://www.nba.com/stats/player/203085/career?PerMode=Totals
# https://www.nba.com/stats/player/203497/career?PerMode=Totals
# https://www.nba.com/stats/player/1626157/career?PerMode=Totals
# https://www.nba.com/stats/player/1630568/career?PerMode=Totals
# https://www.nba.com/stats/player/1628983/career?PerMode=Totals
# https://www.nba.com/stats/player/1630581/career?PerMode=Totals
# https://www.nba.com/stats/player/1629652/career?PerMode=Totals
# https://www.nba.com/stats/player/1631119/career?PerMode=Totals
# https://www.nba.com/stats/player/1631096/career?PerMode=Totals
# https://www.nba.com/stats/player/1631114/career?PerMode=Totals
# https://www.nba.com/stats/player/1630198/career?PerMode=Totals
# https://www.nba.com/stats/player/1630322/career?PerMode=Totals
# https://www.nba.com/stats/player/1631172/career?PerMode=Totals
# https://www.nba.com/stats/player/1630197/career?PerMode=Totals
# https://www.nba.com/stats/player/1630598/career?PerMode=Totals
# https://www.nba.com/stats/player/1630544/career?PerMode=Totals
# https://www.nba.com/stats/player/203488/career?PerMode=Totals
# https://www.nba.com/stats/player/1629026/career?PerMode=Totals
# https://www.nba.com/stats/player/1630526/career?PerMode=Totals
# https://www.nba.com/stats/player/1629647/career?PerMode=Totals
# https://www.nba.com/stats/player/1630647/career?PerMode=Totals
# https://www.nba.com/stats/player/203081/career?PerMode=Totals
# https://www.nba.com/stats/player/1627780/career?PerMode=Totals
# https://www.nba.com/stats/player/1629014/career?PerMode=Totals
# https://www.nba.com/stats/player/1630570/career?PerMode=Totals
# https://www.nba.com/stats/player/1630535/career?PerMode=Totals
# https://www.nba.com/stats/player/1630553/career?PerMode=Totals
# https://www.nba.com/stats/player/203924/career?PerMode=Totals
# https://www.nba.com/stats/player/1629642/career?PerMode=Totals
# https://www.nba.com/stats/player/1628404/career?PerMode=Totals
# https://www.nba.com/stats/player/1631101/career?PerMode=Totals
# https://www.nba.com/stats/player/1631219/career?PerMode=Totals
# https://www.nba.com/stats/player/1629234/career?PerMode=Totals
# https://www.nba.com/stats/player/1626159/career?PerMode=Totals
# https://www.nba.com/stats/player/203994/career?PerMode=Totals
# https://www.nba.com/stats/player/1630846/career?PerMode=Totals
# https://www.nba.com/stats/player/1631133/career?PerMode=Totals
# https://www.nba.com/stats/player/1629659/career?PerMode=Totals
# https://www.nba.com/stats/player/203903/career?PerMode=Totals
# https://www.nba.com/stats/player/1629012/career?PerMode=Totals
# https://www.nba.com/stats/player/1627736/career?PerMode=Totals
# https://www.nba.com/stats/player/1629638/career?PerMode=Totals
# https://www.nba.com/stats/player/1629020/career?PerMode=Totals
# https://www.nba.com/stats/player/1630195/career?PerMode=Totals
# https://www.nba.com/stats/player/201144/career?PerMode=Totals
# https://www.nba.com/stats/player/1631323/career?PerMode=Totals
# https://www.nba.com/stats/player/1628962/career?PerMode=Totals
# https://www.nba.com/stats/player/200752/career?PerMode=Totals
# https://www.nba.com/stats/player/1628374/career?PerMode=Totals
# https://www.nba.com/stats/player/1631117/career?PerMode=Totals
# https://www.nba.com/stats/player/1630695/career?PerMode=Totals
# https://www.nba.com/stats/player/1630534/career?PerMode=Totals
# https://www.nba.com/stats/player/1630548/career?PerMode=Totals
# https://www.nba.com/stats/player/203482/career?PerMode=Totalshttps://www.nba.com/stats/player/1630228/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1628978/career?PerMode=Totals
# https://www.nba.com/stats/player/203210/career?PerMode=Totals
# https://www.nba.com/stats/player/1631157/career?PerMode=Totals
# https://www.nba.com/stats/player/1629673/career?PerMode=Totals
# https://www.nba.com/stats/player/1630541/career?PerMode=Totals
# https://www.nba.com/stats/player/1626172/career?PerMode=Totals
# https://www.nba.com/stats/player/1631116/career?PerMode=Totals
# https://www.nba.com/stats/player/2738/career?PerMode=Totals
# https://www.nba.com/stats/player/1629660/career?PerMode=Totals
# https://www.nba.com/stats/player/202691/career?PerMode=Totals
# https://www.nba.com/stats/player/203952/career?PerMode=Totals
# https://www.nba.com/stats/player/203110/career?PerMode=Totals
# https://www.nba.com/stats/player/201939/career?PerMode=Totals
# https://www.nba.com/stats/player/1630164/career?PerMode=Totals
# https://www.nba.com/stats/player/1630237/career?PerMode=Totals
# https://www.nba.com/stats/player/202704/career?PerMode=Totals
# https://www.nba.com/stats/player/202695/career?PerMode=Totals
# https://www.nba.com/stats/player/1630527/career?PerMode=Totals
# https://www.nba.com/stats/player/1628379/career?PerMode=Totals
# https://www.nba.com/stats/player/1629650/career?PerMode=Totals
# https://www.nba.com/stats/player/1629599/career?PerMode=Totals
# https://www.nba.com/stats/player/202694/career?PerMode=Totals
# https://www.nba.com/stats/player/202322/career?PerMode=Totals
# https://www.nba.com/stats/player/202331/career?PerMode=Totals
# https://www.nba.com/stats/player/1629611/career?PerMode=Totals
# https://www.nba.com/stats/player/1630554/career?PerMode=Totals
# https://www.nba.com/stats/player/203496/career?PerMode=Totalshttps://www.nba.com/stats/player/1626181/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1631217/career?PerMode=Totals
# https://www.nba.com/stats/player/201587/career?PerMode=Totals
# https://www.nba.com/stats/player/1627826/career?PerMode=Totals
# https://www.nba.com/stats/player/201566/career?PerMode=Totals
# https://www.nba.com/stats/player/203076/career?PerMode=Totals
# https://www.nba.com/stats/player/1629022/career?PerMode=Totals
# https://www.nba.com/stats/player/2544/career?PerMode=Totals
# https://www.nba.com/stats/player/1628972/career?PerMode=Totals
# https://www.nba.com/stats/player/1631108/career?PerMode=Totals
# https://www.nba.com/stats/player/1629134/career?PerMode=Totals
# https://www.nba.com/stats/player/1630590/career?PerMode=Totals
# https://www.nba.com/stats/player/1630559/career?PerMode=Totals
# https://www.nba.com/stats/player/203471/career?PerMode=Totals
# https://www.nba.com/stats/player/1631306/career?PerMode=Totals
# https://www.nba.com/stats/player/201976/career?PerMode=Totals
# https://www.nba.com/stats/player/1627745/career?PerMode=Totals
# https://www.nba.com/stats/player/1628418/career?PerMode=Totals
# https://www.nba.com/stats/player/1629117/career?PerMode=Totals
# https://www.nba.com/stats/player/1630346/career?PerMode=Totals
# https://www.nba.com/stats/player/1629308/career?PerMode=Totals
# https://www.nba.com/stats/player/1628470/career?PerMode=Totals
# https://www.nba.com/stats/player/1626164/career?PerMode=Totals
# https://www.nba.com/stats/player/1629006/career?PerMode=Totals
# https://www.nba.com/stats/player/101108/career?PerMode=Totals
# https://www.nba.com/stats/player/1630613/career?PerMode=Totalshttps://www.nba.com/stats/player/1627814/career?PerMode=Totals
#
# https://www.nba.com/stats/player/1629111/career?PerMode=Totals
# https://www.nba.com/stats/player/1630688/career?PerMode=Totals
# https://www.nba.com/stats/player/1629013/career?PerMode=Totals
# https://www.nba.com/stats/player/1626166/career?PerMode=Totals
# https://www.nba.com/stats/player/202687/career?PerMode=Totals
# https://www.nba.com/stats/player/203967/career?PerMode=Totals
# https://www.nba.com/stats/player/1629028/career?PerMode=Totals
# https://www.nba.com/stats/player/1629661/career?PerMode=Totals
# https://www.nba.com/stats/player/1628969/career?PerMode=Totals
# https://www.nba.com/stats/player/203109/career?PerMode=Totals
# https://www.nba.com/stats/player/1628370/career?PerMode=Totals
# https://www.nba.com/stats/player/1629056/career?PerMode=Totals
# https://www.nba.com/stats/player/1628368/career?PerMode=Totals
# https://www.nba.com/stats/player/1629002/career?PerMode=Totals
# https://www.nba.com/stats/player/203521/career?PerMode=Totals
# https://www.nba.com/stats/player/1628989/career?PerMode=Totals
# https://www.nba.com/stats/player/1627734/career?PerMode=Totals
# https://www.nba.com/stats/player/1631099/career?PerMode=Totals
# https://www.nba.com/stats/player/1630558/career?PerMode=Totals
# https://www.nba.com/stats/player/1631320/career?PerMode=Totals
# https://www.nba.com/stats/player/1626158/career?PerMode=Totals
# https://www.nba.com/stats/player/1631165/career?PerMode=Totals
# https://www.nba.com/stats/player/203458/career?PerMode=Totalshttps://www.nba.com/stats/player/1629644/career?PerMode=Totals
#
# https://www.nba.com/stats/player/203084/career?PerMode=Totals
# https://www.nba.com/stats/player/1626168/career?PerMode=Totals
# https://www.nba.com/stats/player/1629674/career?PerMode=Totals
# https://www.nba.com/stats/player/201580/career?PerMode=Totals
# https://www.nba.com/stats/player/1629033/career?PerMode=Totals
# https://www.nba.com/stats/player/1630267/career?PerMode=Totals
# https://www.nba.com/stats/player/1630702/career?PerMode=Totals
# https://www.nba.com/stats/player/203939/career?PerMode=Totals
# https://www.nba.com/stats/player/1630182/career?PerMode=Totals
# https://www.nba.com/stats/player/1627827/career?PerMode=Totals
# https://www.nba.com/stats/player/203501/career?PerMode=Totals
# https://www.nba.com/stats/player/1628373/career?PerMode=Totals
# https://www.nba.com/stats/player/1628416/career?PerMode=Totals
# https://www.nba.com/stats/player/1630593/career?PerMode=Totals
# https://www.nba.com/stats/player/203493/career?PerMode=Totals
# https://www.nba.com/stats/player/203915/career?PerMode=Totals
# https://www.nba.com/stats/player/1626174/career?PerMode=Totals
# https://www.nba.com/stats/player/1628467/career?PerMode=Totals
# https://www.nba.com/stats/player/202722/career?PerMode=Totals
# https://www.nba.com/stats/player/1629029/career?PerMode=Totals
# https://www.nba.com/stats/player/1631102/career?PerMode=Totals
# https://www.nba.com/stats/player/1631095/career?PerMode=Totals
# https://www.nba.com/stats/player/1629645/career?PerMode=Totals
# https://www.nba.com/stats/player/1630224/career?PerMode=Totals
# https://www.nba.com/stats/player/1630620/career?PerMode=Totals
# https://www.nba.com/stats/player/1630231/career?PerMode=Totals
# https://www.nba.com/stats/player/1630256/career?PerMode=Totals
# https://www.nba.com/stats/player/1630528/career?PerMode=Totals
# https://www.nba.com/stats/player/201569/career?PerMode=Totals
# https://www.nba.com/stats/player/1631309/career?PerMode=Totals
# https://www.nba.com/stats/player/1630227/career?PerMode=Totals
# https://www.nba.com/stats/player/1630586/career?PerMode=Totals
# https://www.nba.com/stats/player/1631106/career?PerMode=Totals
# https://www.nba.com/stats/player/1628981/career?PerMode=Totals
# https://www.nba.com/stats/player/1629726/career?PerMode=Totals
# https://www.nba.com/stats/player/1630578/career?PerMode=Totals
# https://www.nba.com/stats/player/1626246/career?PerMode=Totals
# https://www.nba.com/stats/player/1631113/career?PerMode=Totals
# https://www.nba.com/stats/player/1630214/career?PerMode=Totals
# https://www.nba.com/stats/player/1631222/career?PerMode=Totals
# https://www.nba.com/stats/player/203500/career?PerMode=Totals
# https://www.nba.com/stats/player/1631246/career?PerMode=Totals
# https://www.nba.com/stats/player/1631254/career?PerMode=Totals
# https://www.nba.com/stats/player/1630583/career?PerMode=Totals
# https://www.nba.com/stats/player/1630533/career?PerMode=Totals
# https://www.nba.com/stats/player/1629630/career?PerMode=Totals
# https://www.nba.com/stats/player/1628991/career?PerMode=Totals
# https://www.nba.com/stats/player/201980/career?PerMode=Totals
# https://www.nba.com/stats/player/1629634/career?PerMode=Totals
# https://www.nba.com/stats/player/1626145/career?PerMode=Totals
# https://www.nba.com/stats/player/1630217/career?PerMode=Totals
# https://www.nba.com/stats/player/1628415/career?PerMode=Totals
# https://www.nba.com/stats/player/1631223/career?PerMode=Totals
# https://www.nba.com/stats/player/1629723/career?PerMode=Totals
# https://www.nba.com/stats/player/1630604/career?PerMode=Totals
# https://www.nba.com/stats/player/1631220/career?PerMode=Totals
# https://www.nba.com/stats/player/1629627/career?PerMode=Totals
# https://www.nba.com/stats/player/203468/career?PerMode=Totals
# https://www.nba.com/stats/player/1628984/career?PerMode=Totals
# https://www.nba.com/stats/player/1630529/career?PerMode=Totals
# https://www.nba.com/stats/player/1630230/career?PerMode=Totals
# https://www.nba.com/stats/player/1626195/career?PerMode=Totals
# https://www.nba.com/stats/player/1629637/career?PerMode=Totals
# https://www.nba.com/stats/player/1630700/career?PerMode=Totals
# https://www.nba.com/stats/player/1630184/career?PerMode=Totals
# https://www.nba.com/stats/player/1627742/career?PerMode=Totals
# https://www.nba.com/stats/player/1630631/career?PerMode=Totals
# https://www.nba.com/stats/player/202685/career?PerMode=Totals
# https://www.nba.com/stats/player/1626204/career?PerMode=Totals
# https://www.nba.com/stats/player/1630530/career?PerMode=Totals
# https://www.nba.com/stats/player/202066/career?PerMode=Totals
# https://www.nba.com/stats/player/1629640/career?PerMode=Totals
# https://www.nba.com/stats/player/1626196/career?PerMode=Totals
# https://www.nba.com/stats/player/1631110/career?PerMode=Totals
# https://www.nba.com/stats/player/1631104/career?PerMode=Totals
# https://www.nba.com/stats/player/203926/career?PerMode=Totals
# https://www.nba.com/stats/player/1629676/career?PerMode=Totals
# https://www.nba.com/stats/player/1631103/career?PerMode=Totals
# https://www.nba.com/stats/player/1628380/career?PerMode=Totals
# https://www.nba.com/stats/player/1630170/career?PerMode=Totals
# https://www.nba.com/stats/player/1627751/career?PerMode=Totals
# https://www.nba.com/stats/player/1631230/career?PerMode=Totals
# https://www.nba.com/stats/player/1629646/career?PerMode=Totals
# https://www.nba.com/stats/player/1628966/career?PerMode=Totals
# https://www.nba.com/stats/player/1630200/career?PerMode=Totals
# https://www.nba.com/stats/player/1629641/career?PerMode=Totals
# https://www.nba.com/stats/player/203476/career?PerMode=Totals
# https://www.nba.com/stats/player/1631160/career?PerMode=Totals
#      Player ID   PPG  RPG  APG   PIE
# 0      1628369  31.9  7.4  3.9  17.5
# 1       203943   1.9  3.0  0.3   2.5
# 2      1627759  25.4  6.8  3.5  12.0
# 3       201568  11.7  4.7  1.5   9.9
# 4      1628401   8.9  3.2  3.1   8.1
# ..         ...   ...  ...  ...   ...
# 496    1628966   NaN  NaN  NaN   NaN
# 497    1630200   NaN  NaN  NaN   NaN
# 498    1629641   NaN  NaN  NaN   NaN
# 499     203476   NaN  NaN  NaN   NaN
# 500    1631160   NaN  NaN  NaN   NaN
#
# [501 rows x 5 columns]

# %%
# quick_stats.to_csv(os.path.join("nba", "player_quick_stats.csv"))

# %% [markdown]
# ## Get Player Career Stats

# %%
def loading_completed(driver) -> bool:
    """Allows the driver to know when the loading animation is over
    
    Args:
        driver (selenium.webdriver.chrome.webdriver.WebDriver): the Selenium driver
    
    Returns:
        bool: whether the loading animation is over
    """
    try:
        element = driver.find_element(By.CSS_SELECTOR, "div[class*=LoadingOverlay]")
    except NoSuchElementException:
        return False
    return element.get_attribute("data-hidden") == "true"

# %%
def get_page_source(url: str) -> str:
    """Opens the player stats page and gets the HTML page source
    
    Args:
        url (str): the player stats URL
    
    Returns:
        str: the player stats HTML
    """
    service = ChromeService(executable_path=ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    # Timeout in seconds
    TIMEOUT = 30
    
    try:
        wait = WebDriverWait(driver, timeout=TIMEOUT)
        driver.get(url)
        wait.until(loading_completed)
        page_source = driver.page_source
        driver.quit()
        return page_source
    except Exception:
        raise Exception("Something went wrong!")

# %%
def get_player_info(player_id: int) -> pd.DataFrame:
    """Gets the player's career regular season stats
    
    Args:
        player_id: the player's ID
    
    Returns:
        pd.DataFrame: the player's career stats
    """
    url = create_player_query(player_id=player_id)
    print(url)
    
    # Retrieve the player's stats page
    # Tries multiple times
    i = 0
    while True:
        try:
            page_content = get_page_source(url)
        except Exception:
            print(f"Iteration #{i}: Issue getting page contents")
            i += 1
    
    # Looks for the CAREER REGULAR SEASON STATS table
    soup = BeautifulSoup(page_content, "html.parser")
    table = soup.find("table", {"class": re.compile("Crom_table*")})

    try:
        # Collect and format the table data
        cols = [elem.text for elem in table.find_all("th")[3:]]
        rows = [row.text for row in table.find_all("td")]
        output = []
        row = []
        for i, v in enumerate(rows):
            if i != 0 and i % len(cols) == 0:
                output.append(row)
                row = []

            row.append(v)

        df = pd.DataFrame(output, columns=cols)
        df["PLAYER ID"] = player_id
        return df
    except Exception:
        # New players don't have stats, so return an empty DataFrame
        if soup.find("div", string="No data available"):
            print(f"No data available for player: {player_id}")
            return pd.DataFrame()
        print("There seems to be another issue!!")

# %%
def get_all_player_info(player_ids: List[int]) -> pd.DataFrame:
    """Get all the player's career statistics. I don't use threads with Selenium because
    Chrome is a RAM-hog, and it wastes more time than just visiting a site one after another.
    
    Args:
        player_ids (List[int]): all the player IDs
    
    Returns:
        pd.DataFrame: all player career stats
    """
    output = []
    for idx, player_id in enumerate(player_ids):
        print(f"#{idx}", end=" ")
        output.append(get_player_info(player_id))
    return pd.concat(output).reset_index(drop=True)

# %%
players_info = get_all_player_info(player_ids=player_ids[:5])
# Out:
# #0 https://www.nba.com/stats/player/1628369/career?PerMode=Totals
# [WDM] - Downloading: 100%|█████████████████| 7.72M/7.72M [00:00<00:00, 31.7MB/s]
# Iteration #0: Issue getting page contents
# Iteration #1: Issue getting page contents
# KeyboardInterrupt

# %%
def process_career_stats(df: pd.DataFrame) -> pd.DataFrame:
    """Process the career stats. Changing the column names and making the statistics into numeric types
    instead of strings.
    
    Args:
        df (pd.DataFrame): the raw career stats
        
    Returns:
        pd.DataFrame: the processed career stats
    """
    df = df.copy(deep=True)
    }    df.rename(columns={
        "TEAM": "Team", 
        "AGE": "Age",
        "PLAYER ID": "Player ID",
    }, inplace=True)
    
    int_cols = list(set(df.columns) - {"Season", "Team"})
    df[int_cols] = df[int_cols].apply(pd.to_numeric)
    return df

# %%
career_stats = process_career_stats(players_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 career_stats = process_career_stats(players_info)
#
# NameError: name 'players_info' is not defined

# %%
# career_stats.to_csv(os.path.join("nba", "player_info.csv"))
